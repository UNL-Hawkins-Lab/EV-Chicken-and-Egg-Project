# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_parquet('Data/Transport/Experian Registrations/Sum of registrations.parquet')

# %%
df1
# Out:
# Vehicle Fuel Type  24kw Electric~Electric  60kw Electric~Electric  \
# uniqueid Year
# 01000    2012                         NaN                     NaN
#          2014                         NaN                     NaN
#          2016                         NaN                     NaN
#          2018                         NaN                     NaN
#          2020                         NaN                     NaN
# ...                                   ...                     ...
# 72151    2018                         NaN                     NaN
#          2020                         NaN                     NaN
# 72153    2016                         NaN                     NaN
#          2018                         NaN                     NaN
#          2020                         NaN                     NaN
#
# Vehicle Fuel Type  85kw Electric~Electric  90kw Electric~Electric   CNG  \
# uniqueid Year
# ...
